# %%
# %ls
# Out:
# sample_data/

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 5.7 MB/s eta 0:00:00
# ...
# Launching Xterm...

# %%
apt install screen ztd
# Out:
#   File "/tmp/ipykernel_1133/2541697489.py", line 1
#     apt install screen ztd
#         ^
# SyntaxError: invalid syntax

# %%
# %xterm
# Out:
# Launching Xterm...
